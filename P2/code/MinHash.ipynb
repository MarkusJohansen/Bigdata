# %%
import numpy as np
import hashlib

# %% [markdown]
# Name A:
#
# Name B:

# %%
#Four (4) 'relevant' TDT4305 sentences

Sentence_1 = "The Big Data platform for students is Blackboard"
Sentence_2 = "Questions on MinHash project by NTNU students is on Piazza"
Sentence_3 = "NTNU Big Data platform are Blackboard and Piazza"
Sentence_4 = "The project data for students are on Blackboard not Piazza"

# %%
unique_words = [] # Enter the unique words list here

##* OUR CODE STARTS HERE

# finds k = 1 shingles and add all of them to the unique_words list
for sentence in [Sentence_1, Sentence_2, Sentence_3, Sentence_4]:
    unique_words += sentence.split()
    
# remove duplicates and sort alphabetically
unique_words = list(set(unique_words))
unique_words.sort()

print(unique_words)

##* OUR CODE ENDS HERE
# Out:
# ['The', 'Big', 'Data', 'platform', 'for', 'students', 'is', 'Blackboard']
# ['The', 'Big', 'Data', 'platform', 'for', 'students', 'is', 'Blackboard', 'Questions', 'on', 'MinHash', 'project', 'by', 'NTNU', 'students', 'is', 'on', 'Piazza']
# ['The', 'Big', 'Data', 'platform', 'for', 'students', 'is', 'Blackboard', 'Questions', 'on', 'MinHash', 'project', 'by', 'NTNU', 'students', 'is', 'on', 'Piazza', 'NTNU', 'Big', 'Data', 'platform', 'are', 'Blackboard', 'and', 'Piazza']
# ['The', 'Big', 'Data', 'platform', 'for', 'students', 'is', 'Blackboard', 'Questions', 'on', 'MinHash', 'project', 'by', 'NTNU', 'students', 'is', 'on', 'Piazza', 'NTNU', 'Big', 'Data', 'platform', 'are', 'Blackboard', 'and', 'Piazza', 'The', 'project', 'data', 'for', 'students', 'are', 'on', 'Blackboard', 'not', 'Piazza']
# ['Piazza', 'are', 'by', 'NTNU', 'MinHash', 'is', 'platform', 'Blackboard', 'project', 'The', 'Questions', 'Big', 'and', 'not', 'Data', 'students', 'on', 'for', 'data']
# ['Big', 'Blackboard', 'Data', 'MinHash', 'NTNU', 'Piazza', 'Questions', 'The', 'and', 'are', 'by', 'data', 'for', 'is', 'not', 'on', 'platform', 'project', 'students']

# %%
# User input

print(f"Format: ['word', 'word', 'word' ...] & watch out for white spaces before comma")
user_input = str(input("Enter your created list of unique words: ")) 

f = open("encrypted_dictionary.txt", "r")
encrypted_words = f.read()


# Hash the user input
hashed_user_input = hashlib.sha256(user_input.encode()).hexdigest()

# Compare with the stored hash
if hashed_user_input == encrypted_words:
    print("Correct! Your dictionary matched!")
else:
    print("Incorrect! Try again.")
# Out:
# Format: ['word', 'word', 'word' ...] & watch out for white spaces before comma
# Incorrect! Try again.

# %%
Input_Matrix = [] # Create an empty array of input matrix

# %%
## Compute the values for the input matrix here ##

# %%
Sig_M = [] # Create a MinHash signature matrix array with inf values

# %%
# Generate hash functions

# %%
hash_1 = []

# %%
hash_2 = []

# %%
hash_3 = []

# %%
hash_list = [hash_1, hash_2, hash_3]

# %%
hash_list
# Out:
# [[], [], []]

# %%
## Using the hash functions and the input matrix compute the MinHash signature matrix here ##

# %%
# print the updated MinHash signature matrix

Sig_M
# Out:
# []
